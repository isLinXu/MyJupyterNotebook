# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np

# %%
transform = transforms.Compose([
    transforms.Resize(32),
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=256,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=100,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# CUDA 기기 상에서 돌린다고 가정하면, 이와 같이 하면 CUDA 장치를 출력합니다:

print(device)
# Out:
# cuda:0

# %%
class VGGNet(nn.Module):
    def __init__(self):
        super(VGGNet, self).__init__()
        
        self.features = nn.Sequential(
            
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            
            nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn. Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
        )
        
        self.classifier = nn.Sequential(
#             nn.Dropout(p=0.2),
            nn.Linear(1 * 1 * 512, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),
            nn.Linear(512, 512),
            nn.ReLU(inplace=True),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.shape[0], -1)
        x = self.classifier(x)
        return x

      
net = VGGNet()
net=net.cuda()
net
# Out:
# VGGNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.2)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): ReLU(inplace)
#     (5): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
# optimizer = optim.Adam(net.parameters())
# optimizer = optim.SGD(net.parameters(), lr=0.1, momentum=0.9, nesterov=True)
optimizer = torch.optim.SGD(net.parameters(), lr=0.1, momentum=0.9, nesterov=True)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer,200)

# %%
def test():
  test_total = 0
  test_correct = 0
  class_correct = list(0. for i in range(10))
  class_total = list(0. for i in range(10))

  with torch.no_grad():
    for data in testloader:
      images, labels = data
      images = images.cuda()
      labels = labels.cuda()
      outputs = net(images)
      _, predicted = torch.max(outputs.data, 1)
      test_total += labels.size(0)
      test_correct += (predicted == labels).sum().item()

  print('Accuracy of the network on the 10000 test images: %d %%' % (
      100 * test_correct / test_total))

# %%
for epoch in range(200):  # 데이터셋을 수차례 반복합니다.
    scheduler.step(epoch)
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        correct = 0
        total = 0
      
        # 입력을 받은 후
        inputs, labels = data
        
        inputs, labels = inputs.to(device), labels.to(device)

        # 변화도(Gradient) 매개변수를 0으로 만든 후
        optimizer.zero_grad()

        # 순전파 + 역전파 + 최적화
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        
        optimizer.step()
        
        # 통계 출력
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
    acc = 100 * correct / total
    print('[%d, %5d] acc: %.3f loss: %.3f' % (epoch + 1, i + 1, acc, running_loss / 196))
    test()
print('Finished Training')
# Out:
# [1,   196] acc: 43.750 loss: 1.637
# Accuracy of the network on the 10000 test images: 51 %
# [2,   196] acc: 71.250 loss: 1.085
# Accuracy of the network on the 10000 test images: 66 %
# [3,   196] acc: 66.250 loss: 0.837
# Accuracy of the network on the 10000 test images: 69 %
# [4,   196] acc: 76.250 loss: 0.721
# Accuracy of the network on the 10000 test images: 73 %
# [5,   196] acc: 81.250 loss: 0.635
# Accuracy of the network on the 10000 test images: 77 %
# [6,   196] acc: 85.000 loss: 0.567
# Accuracy of the network on the 10000 test images: 78 %
# [7,   196] acc: 81.250 loss: 0.519
# Accuracy of the network on the 10000 test images: 80 %
# [8,   196] acc: 70.000 loss: 0.476
# Accuracy of the network on the 10000 test images: 81 %
# [9,   196] acc: 90.000 loss: 0.434
# Accuracy of the network on the 10000 test images: 82 %
# [10,   196] acc: 82.500 loss: 0.401
# Accuracy of the network on the 10000 test images: 82 %
# [11,   196] acc: 86.250 loss: 0.372
# Accuracy of the network on the 10000 test images: 84 %
# [12,   196] acc: 92.500 loss: 0.346
# Accuracy of the network on the 10000 test images: 85 %
# [13,   196] acc: 80.000 loss: 0.331
# Accuracy of the network on the 10000 test images: 84 %
# [14,   196] acc: 86.250 loss: 0.304
# Accuracy of the network on the 10000 test images: 85 %
# [15,   196] acc: 83.750 loss: 0.287
# Accuracy of the network on the 10000 test images: 85 %
# [16,   196] acc: 88.750 loss: 0.273
# Accuracy of the network on the 10000 test images: 86 %
# [17,   196] acc: 92.500 loss: 0.254
# Accuracy of the network on the 10000 test images: 86 %
# [18,   196] acc: 87.500 loss: 0.240
# Accuracy of the network on the 10000 test images: 86 %
# [19,   196] acc: 92.500 loss: 0.227
# Accuracy of the network on the 10000 test images: 86 %
# [20,   196] acc: 95.000 loss: 0.210
# Accuracy of the network on the 10000 test images: 86 %
# [21,   196] acc: 93.750 loss: 0.195
# Accuracy of the network on the 10000 test images: 86 %
# [22,   196] acc: 91.250 loss: 0.192
# Accuracy of the network on the 10000 test images: 87 %
# [23,   196] acc: 93.750 loss: 0.180
# Accuracy of the network on the 10000 test images: 87 %
# [24,   196] acc: 96.250 loss: 0.173
# Accuracy of the network on the 10000 test images: 88 %
# [25,   196] acc: 91.250 loss: 0.162
# Accuracy of the network on the 10000 test images: 86 %
# [26,   196] acc: 96.250 loss: 0.157
# Accuracy of the network on the 10000 test images: 87 %
# [27,   196] acc: 88.750 loss: 0.144
# Accuracy of the network on the 10000 test images: 88 %
# [28,   196] acc: 91.250 loss: 0.140
# Accuracy of the network on the 10000 test images: 88 %
# [29,   196] acc: 92.500 loss: 0.132
# Accuracy of the network on the 10000 test images: 88 %
# [30,   196] acc: 95.000 loss: 0.127
# Accuracy of the network on the 10000 test images: 88 %
# [31,   196] acc: 98.750 loss: 0.120
# Accuracy of the network on the 10000 test images: 88 %
# [32,   196] acc: 96.250 loss: 0.114
# Accuracy of the network on the 10000 test images: 88 %
# [33,   196] acc: 98.750 loss: 0.107
# Accuracy of the network on the 10000 test images: 88 %
# [34,   196] acc: 96.250 loss: 0.102
# Accuracy of the network on the 10000 test images: 88 %
# [35,   196] acc: 95.000 loss: 0.095
# Accuracy of the network on the 10000 test images: 88 %
# [36,   196] acc: 98.750 loss: 0.093
# Accuracy of the network on the 10000 test images: 89 %
# [37,   196] acc: 100.000 loss: 0.085
# Accuracy of the network on the 10000 test images: 88 %
# [38,   196] acc: 95.000 loss: 0.087
# Accuracy of the network on the 10000 test images: 88 %
# [39,   196] acc: 95.000 loss: 0.083
# Accuracy of the network on the 10000 test images: 88 %
# [40,   196] acc: 93.750 loss: 0.079
# Accuracy of the network on the 10000 test images: 88 %
# [41,   196] acc: 98.750 loss: 0.076
# Accuracy of the network on the 10000 test images: 89 %
# [42,   196] acc: 98.750 loss: 0.069
# Accuracy of the network on the 10000 test images: 89 %
# [43,   196] acc: 95.000 loss: 0.069
# Accuracy of the network on the 10000 test images: 89 %
# [44,   196] acc: 96.250 loss: 0.067
# Accuracy of the network on the 10000 test images: 88 %
# [45,   196] acc: 98.750 loss: 0.061
# Accuracy of the network on the 10000 test images: 89 %
# [46,   196] acc: 100.000 loss: 0.058
# Accuracy of the network on the 10000 test images: 89 %
# [47,   196] acc: 98.750 loss: 0.056
# Accuracy of the network on the 10000 test images: 89 %
# [48,   196] acc: 98.750 loss: 0.053
# Accuracy of the network on the 10000 test images: 89 %
# [49,   196] acc: 95.000 loss: 0.053
# Accuracy of the network on the 10000 test images: 88 %
# [50,   196] acc: 96.250 loss: 0.052
# Accuracy of the network on the 10000 test images: 89 %
# [51,   196] acc: 97.500 loss: 0.048
# Accuracy of the network on the 10000 test images: 89 %
# [52,   196] acc: 98.750 loss: 0.048
# Accuracy of the network on the 10000 test images: 89 %
# [53,   196] acc: 98.750 loss: 0.044
# Accuracy of the network on the 10000 test images: 89 %
# [54,   196] acc: 97.500 loss: 0.040
# Accuracy of the network on the 10000 test images: 89 %
# [55,   196] acc: 97.500 loss: 0.039
# Accuracy of the network on the 10000 test images: 89 %
# [56,   196] acc: 98.750 loss: 0.038
# Accuracy of the network on the 10000 test images: 90 %
# [57,   196] acc: 100.000 loss: 0.037
# Accuracy of the network on the 10000 test images: 89 %
# [58,   196] acc: 100.000 loss: 0.035
# Accuracy of the network on the 10000 test images: 89 %
# [59,   196] acc: 100.000 loss: 0.038
# Accuracy of the network on the 10000 test images: 90 %
# [60,   196] acc: 97.500 loss: 0.032
# Accuracy of the network on the 10000 test images: 89 %
# [61,   196] acc: 96.250 loss: 0.031
# Accuracy of the network on the 10000 test images: 89 %
# [62,   196] acc: 97.500 loss: 0.031
# Accuracy of the network on the 10000 test images: 89 %
# [63,   196] acc: 95.000 loss: 0.030
# Accuracy of the network on the 10000 test images: 90 %
# [64,   196] acc: 98.750 loss: 0.033
# Accuracy of the network on the 10000 test images: 89 %
# [65,   196] acc: 100.000 loss: 0.028
# Accuracy of the network on the 10000 test images: 89 %
# [66,   196] acc: 98.750 loss: 0.028
# Accuracy of the network on the 10000 test images: 89 %
# [67,   196] acc: 100.000 loss: 0.025
# Accuracy of the network on the 10000 test images: 90 %
# [68,   196] acc: 97.500 loss: 0.024
# Accuracy of the network on the 10000 test images: 89 %
# [69,   196] acc: 98.750 loss: 0.023
# Accuracy of the network on the 10000 test images: 90 %
# [70,   196] acc: 100.000 loss: 0.021
# Accuracy of the network on the 10000 test images: 89 %
# [71,   196] acc: 98.750 loss: 0.022
# Accuracy of the network on the 10000 test images: 89 %
# [72,   196] acc: 98.750 loss: 0.021
# Accuracy of the network on the 10000 test images: 90 %
# [73,   196] acc: 98.750 loss: 0.020
# Accuracy of the network on the 10000 test images: 90 %
# [74,   196] acc: 96.250 loss: 0.021
# Accuracy of the network on the 10000 test images: 90 %
# [75,   196] acc: 100.000 loss: 0.020
# Accuracy of the network on the 10000 test images: 90 %
# [76,   196] acc: 100.000 loss: 0.015
# Accuracy of the network on the 10000 test images: 90 %
# [77,   196] acc: 98.750 loss: 0.018
# Accuracy of the network on the 10000 test images: 90 %
# [78,   196] acc: 100.000 loss: 0.018
# Accuracy of the network on the 10000 test images: 89 %
# [79,   196] acc: 100.000 loss: 0.018
# Accuracy of the network on the 10000 test images: 90 %
# [80,   196] acc: 100.000 loss: 0.016
# Accuracy of the network on the 10000 test images: 90 %
# [81,   196] acc: 97.500 loss: 0.014
# Accuracy of the network on the 10000 test images: 90 %
# [82,   196] acc: 100.000 loss: 0.014
# Accuracy of the network on the 10000 test images: 90 %
# [83,   196] acc: 98.750 loss: 0.011
# Accuracy of the network on the 10000 test images: 90 %
# [84,   196] acc: 100.000 loss: 0.012
# Accuracy of the network on the 10000 test images: 90 %
# [85,   196] acc: 98.750 loss: 0.014
# Accuracy of the network on the 10000 test images: 90 %
# [86,   196] acc: 100.000 loss: 0.012
# Accuracy of the network on the 10000 test images: 90 %
# [87,   196] acc: 98.750 loss: 0.010
# Accuracy of the network on the 10000 test images: 90 %
# [88,   196] acc: 100.000 loss: 0.010
# Accuracy of the network on the 10000 test images: 90 %
# [89,   196] acc: 97.500 loss: 0.010
# Accuracy of the network on the 10000 test images: 90 %
# [90,   196] acc: 100.000 loss: 0.010
# Accuracy of the network on the 10000 test images: 90 %
# [91,   196] acc: 98.750 loss: 0.012
# Accuracy of the network on the 10000 test images: 90 %
# [92,   196] acc: 100.000 loss: 0.010
# Accuracy of the network on the 10000 test images: 90 %
# [93,   196] acc: 98.750 loss: 0.009
# Accuracy of the network on the 10000 test images: 90 %
# [94,   196] acc: 100.000 loss: 0.010
# Accuracy of the network on the 10000 test images: 90 %
# [95,   196] acc: 100.000 loss: 0.006
# Accuracy of the network on the 10000 test images: 90 %
# [96,   196] acc: 97.500 loss: 0.008
# Accuracy of the network on the 10000 test images: 90 %
# [97,   196] acc: 100.000 loss: 0.009
# Accuracy of the network on the 10000 test images: 91 %
# [98,   196] acc: 100.000 loss: 0.009
# Accuracy of the network on the 10000 test images: 90 %
# [99,   196] acc: 98.750 loss: 0.007
# Accuracy of the network on the 10000 test images: 90 %
# [100,   196] acc: 98.750 loss: 0.009
# Accuracy of the network on the 10000 test images: 90 %
# [101,   196] acc: 100.000 loss: 0.006
# Accuracy of the network on the 10000 test images: 91 %
# [102,   196] acc: 97.500 loss: 0.005
# Accuracy of the network on the 10000 test images: 91 %
# [103,   196] acc: 100.000 loss: 0.008
# Accuracy of the network on the 10000 test images: 90 %
# [104,   196] acc: 100.000 loss: 0.006
# Accuracy of the network on the 10000 test images: 90 %
# [105,   196] acc: 98.750 loss: 0.007
# Accuracy of the network on the 10000 test images: 91 %
# [106,   196] acc: 97.500 loss: 0.004
# Accuracy of the network on the 10000 test images: 90 %
# [107,   196] acc: 100.000 loss: 0.006
# Accuracy of the network on the 10000 test images: 90 %
# [108,   196] acc: 100.000 loss: 0.004
# Accuracy of the network on the 10000 test images: 90 %
# [109,   196] acc: 100.000 loss: 0.004
# Accuracy of the network on the 10000 test images: 90 %
# [110,   196] acc: 100.000 loss: 0.004
# Accuracy of the network on the 10000 test images: 90 %
# [111,   196] acc: 100.000 loss: 0.005
# Accuracy of the network on the 10000 test images: 90 %
# [112,   196] acc: 100.000 loss: 0.004
# Accuracy of the network on the 10000 test images: 90 %
# [113,   196] acc: 100.000 loss: 0.005
# Accuracy of the network on the 10000 test images: 90 %
# [114,   196] acc: 100.000 loss: 0.003
# Accuracy of the network on the 10000 test images: 91 %
# [115,   196] acc: 100.000 loss: 0.003
# Accuracy of the network on the 10000 test images: 91 %
# [116,   196] acc: 100.000 loss: 0.003
# Accuracy of the network on the 10000 test images: 91 %
# [117,   196] acc: 100.000 loss: 0.003
# Accuracy of the network on the 10000 test images: 90 %
# [118,   196] acc: 100.000 loss: 0.002
# Accuracy of the network on the 10000 test images: 91 %
# [119,   196] acc: 98.750 loss: 0.003
# Accuracy of the network on the 10000 test images: 91 %
# [120,   196] acc: 98.750 loss: 0.003
# Accuracy of the network on the 10000 test images: 91 %
# [121,   196] acc: 100.000 loss: 0.003
# Accuracy of the network on the 10000 test images: 91 %
# [122,   196] acc: 100.000 loss: 0.002
# Accuracy of the network on the 10000 test images: 91 %
# [123,   196] acc: 100.000 loss: 0.002
# Accuracy of the network on the 10000 test images: 91 %
# [124,   196] acc: 100.000 loss: 0.002
# Accuracy of the network on the 10000 test images: 91 %
# [125,   196] acc: 100.000 loss: 0.002
# Accuracy of the network on the 10000 test images: 90 %
# [126,   196] acc: 100.000 loss: 0.002
# Accuracy of the network on the 10000 test images: 91 %
# [127,   196] acc: 100.000 loss: 0.002
# Accuracy of the network on the 10000 test images: 91 %
# [128,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [129,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 90 %
# [130,   196] acc: 100.000 loss: 0.002
# Accuracy of the network on the 10000 test images: 91 %
# [131,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [132,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [133,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [134,   196] acc: 100.000 loss: 0.002
# Accuracy of the network on the 10000 test images: 91 %
# [135,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [136,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 90 %
# [137,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [138,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [139,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [140,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [141,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [142,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [143,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [144,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [145,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [146,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [147,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [148,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [149,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [150,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [151,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [152,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [153,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [154,   196] acc: 98.750 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [155,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [156,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [157,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [158,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [159,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [160,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [161,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [162,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [163,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [164,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [165,   196] acc: 100.000 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [166,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [167,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [168,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [169,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [170,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [171,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [172,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [173,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [174,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [175,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [176,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [177,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [178,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [179,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [180,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [181,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [182,   196] acc: 98.750 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [183,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [184,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [185,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [186,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [187,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [188,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [189,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [190,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [191,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [192,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [193,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [194,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [195,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [196,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [197,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [198,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# [199,   196] acc: 98.750 loss: 0.001
# Accuracy of the network on the 10000 test images: 91 %
# [200,   196] acc: 100.000 loss: 0.000
# Accuracy of the network on the 10000 test images: 91 %
# Finished Training
